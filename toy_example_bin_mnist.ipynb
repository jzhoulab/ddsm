# %% [markdown]
# # Toy Example for Dirichlet Diffusion Score Model

# %% [markdown]
# In this notebook demo, we provide a quick demo on binarized MNIST dataset. Let's load required libraries first.

# %%
import os
from matplotlib import pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torchvision.transforms as transforms


import torch
import functools
from torch.optim import Adam
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision.datasets import MNIST
from torchvision.utils import make_grid
import tqdm


import pandas as pd
import functools
import numpy as np

# Main file which contrains all DDSM logic
from ddsm import *

# %% [markdown]
# ### Loading Presampled Noise

# %% [markdown]
# While Jacobi diffusion evaluation is more expensive than the commonly used diffusion process with Gaussian stationary distribution, all Jacobi diffusion-related computations can be precomputed prior to training and do not add to training time. This is feasible because we only need to generate samples from two starting points, 0 and 1, for any categorical data. Training time sampling is done by choosing randomly from the pre-sampled samples and scores.
#
# For presampling weights, you need to presample everything by running ''presample_noise.p'' script provided in the repo. For example,
# ```
# python presample_noise.py -n 10000 -c 2 -t 400 --out_path . --mode path
# ```
# generates file with 2 categories, 10000 samples, and 400 timepoints. This noise will be used later for training, sampling, and computing negative log likelihood.
#
# Let's load generated file.

# %%
v_one, v_zero, v_one_loggrad, v_zero_loggrad, timepoints = torch.load("steps400.cat2.time4.0.samples10000.pth")

# We have two categories, so the beta parameters are 
alpha = torch.DoubleTensor([1.0])
beta = torch.DoubleTensor([1.0])

# Example of 4 categories to be used with diffusion_factory
# alpha = torch.DoubleTensor([1.0, 1.0, 1.0])
# beta = torch.DoubleTensor([3.0, 2.0, 1.0])

# %% [markdown]
# ### Defining the Model
#
# Now, let's define the score-based model for binarized MNIST data.

# %%
# Model architecture borrowed from https://github.com/yang-song/score_sde
# Note the manuscript experiment on binarized MNIST use a different, larger model

class Dense(nn.Module):
    """
    A fully connected layer that reshapes outputs to feature maps.
    """
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.dense = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        return self.dense(x)[..., None, None]


class ScoreNet(nn.Module):
    """A time-dependent score-based model built upon U-Net architecture."""
    def __init__(self, channels=[32, 64, 128, 256], embed_dim=256):
        """Initialize a time-dependent score-based network.

        Args:
          marginal_prob_std: A function that takes time t and gives the standard
            deviation of the perturbation kernel p_{0t}(x(t) | x(0)).
          channels: The number of channels for feature maps of each resolution.
          embed_dim: The dimensionality of Gaussian random feature embeddings.
        """
        super().__init__()
        # Gaussian random feature embedding layer for time
        self.embed = nn.Sequential(
            GaussianFourierProjection(embed_dim=embed_dim),
            nn.Linear(embed_dim, embed_dim),
        )
        
        # Encoding layers where the resolution decreases
        self.conv1 = nn.Conv2d(2, channels[0], 3, stride=1, bias=False)
        self.dense1 = Dense(embed_dim, channels[0])
        self.gnorm1 = nn.GroupNorm(4, num_channels=channels[0])
        self.conv2 = nn.Conv2d(channels[0], channels[1], 3, stride=2, bias=False)
        self.dense2 = Dense(embed_dim, channels[1])
        self.gnorm2 = nn.GroupNorm(32, num_channels=channels[1])
        self.conv3 = nn.Conv2d(channels[1], channels[2], 3, stride=2, bias=False)
        self.dense3 = Dense(embed_dim, channels[2])
        self.gnorm3 = nn.GroupNorm(32, num_channels=channels[2])
        self.conv4 = nn.Conv2d(channels[2], channels[3], 3, stride=2, bias=False)
        self.dense4 = Dense(embed_dim, channels[3])
        self.gnorm4 = nn.GroupNorm(32, num_channels=channels[3])

        # Decoding layers where the resolution increases
        self.tconv4 = nn.ConvTranspose2d(
            channels[3], channels[2], 3, stride=2, bias=False
        )
        
        self.dense5 = Dense(embed_dim, channels[2])
        self.tgnorm4 = nn.GroupNorm(32, num_channels=channels[2])
        self.tconv3 = nn.ConvTranspose2d(
            channels[2] + channels[2],
            channels[1],
            3,
            stride=2,
            bias=False,
            output_padding=1,
        )
        
        self.dense6 = Dense(embed_dim, channels[1])
        self.tgnorm3 = nn.GroupNorm(32, num_channels=channels[1])
        self.tconv2 = nn.ConvTranspose2d(
            channels[1] + channels[1],
            channels[0],
            3,
            stride=2,
            bias=False,
            output_padding=1,
        )
        self.dense7 = Dense(embed_dim, channels[0])
        self.tgnorm2 = nn.GroupNorm(32, num_channels=channels[0])
        self.tconv1 = nn.ConvTranspose2d(channels[0] + channels[0], 2, 3, stride=1)

        # The swish activation function
        self.act = lambda x: x * torch.sigmoid(x)

    def forward(self, x, t):
        # Obtain the Gaussian random feature embedding for t
        embed = self.act(self.embed(t / 4.0))
        # Encoding path
        h1 = self.conv1(x.permute(0, 3, 1, 2))
        ## Incorporate information from t
        h1 += self.dense1(embed)
        h1 = self.gnorm1(h1)
        h1 = self.act(h1)
        h2 = self.conv2(h1)
        h2 += self.dense2(embed)
        h2 = self.gnorm2(h2)
        h2 = self.act(h2)
        h3 = self.conv3(h2)
        h3 += self.dense3(embed)
        h3 = self.gnorm3(h3)
        h3 = self.act(h3)
        h4 = self.conv4(h3)
        h4 += self.dense4(embed)
        h4 = self.gnorm4(h4)
        h4 = self.act(h4)

        # Decoding path
        h = self.tconv4(h4)
        ## Skip connection from the encoding path
        h += self.dense5(embed)
        h = self.tgnorm4(h)
        h = self.act(h)
        h = self.tconv3(torch.cat([h, h3], dim=1))
        h += self.dense6(embed)
        h = self.tgnorm3(h)
        h = self.act(h)
        h = self.tconv2(torch.cat([h, h2], dim=1))
        h += self.dense7(embed)
        h = self.tgnorm2(h)
        h = self.act(h)
        h = self.tconv1(torch.cat([h, h1], dim=1))

        # some scaling here by time or x may be helpful but no scaling works fine here
        h = h.permute(0, 2, 3, 1)
        h = h - h.mean(axis=-1, keepdims=True)
        return h

# %% [markdown]
# ### Loading Binarized Mnist Data
#
# The following code load MNIST data and create binarized version of it.

# %%
mkdir mnist

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

import os
import joblib
import numpy as np
from urllib.request import urlretrieve


def load_mnist_binarized(root):
    datapath = os.path.join(root, "bin-mnist")
    if not os.path.exists(datapath):
        os.makedirs(datapath)
    dataset = os.path.join(datapath, "mnist.pkl.gz")

    if not os.path.isfile(dataset):

        datafiles = {
            "train": "http://www.cs.toronto.edu/~larocheh/public/"
            "datasets/binarized_mnist/binarized_mnist_train.amat",
            "valid": "http://www.cs.toronto.edu/~larocheh/public/datasets/"
            "binarized_mnist/binarized_mnist_valid.amat",
            "test": "http://www.cs.toronto.edu/~larocheh/public/datasets/"
            "binarized_mnist/binarized_mnist_test.amat",
        }
        datasplits = {}
        for split in datafiles.keys():
            print("Downloading %s data..." % (split))
            datasplits[split] = np.loadtxt(urlretrieve(datafiles[split])[0])

        joblib.dump(
            [datasplits["train"], datasplits["valid"], datasplits["test"]],
            open(dataset, "wb"),
        )

    x_train, x_valid, x_test = joblib.load(open(dataset, "rb"))
    return x_train, x_valid, x_test


class BinMNIST(Dataset):
    """Binary MNIST dataset"""

    def __init__(self, data, device="cpu", transform=None):
        h, w, c = 28, 28, 1
        self.device = device
        self.data = torch.tensor(data, dtype=torch.float).view(-1, c, h, w)
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data[idx]
        if self.transform:
            sample = self.transform(sample)
        return sample.to(self.device)


def get_binmnist_datasets(root, device="cpu"):
    x_train, x_valid, x_test = load_mnist_binarized(root)
    # x_train = np.append(x_train, x_valid, axis=0)  # https://github.com/casperkaae/LVAE/blob/master/run_models.py (line 401)
    return (
        BinMNIST(x_train, device=device),
        BinMNIST(x_valid, device=device),
        BinMNIST(x_test, device=device),
    )


def binary_to_onehot(x):
    xonehot = []
    xonehot.append((x == 1)[..., None])
    xonehot.append((x == 0)[..., None])
    return torch.cat(xonehot, -1)

train_set, valid_set, test_set = get_binmnist_datasets("./mnist")

# %% [markdown]
# Let's load training/validation/test datasets and dataset for importance sampling weights estimation.

# %%
batch_size = 32

# %%
weights_est_dl = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
training_dl = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
valid_data_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=False, num_workers=0)
valid_datasets = []
for x in valid_data_loader:
    valid_datasets.append(x)

# %%
test_dl = DataLoader(test_set, batch_size=batch_size, shuffle=True, num_workers=4)

# %% [markdown]
# ### Global Parameters
#
# We define a few global parameters for our model

# %%
# number of categories are 2 for binarized MNIST data
C = 2  

# device, where code will be run
device = "cuda" # alternative option is "cpu"

# We did not find the randomization strategy useful in our experiments. 
# However, if someone worries about bias introduced by order of categories,
# one can use randomization strategy, which shuffles categories, introduces noise, 
# and then shuffle back.
random_order = False

# For more than >2 categories, speed balancing may improve model score. (see Appendix A.2)
speed_balanced = False  

if speed_balanced:
    s = 2 / (
        torch.ones(C - 1, device=device)
        + torch.arange(C - 1, 0, -1, device=device).float()
    )
else:
    s = torch.ones(C - 1, device=device)
        
# Number of epochs for training
num_epochs = 50

# %% [markdown]
# Jacobi diffusion process converges to Beta stationary distribution, a univariate special case of Dirichlet distribution. Using the connection between Beta distribution and Dirichlet distribution, we construct a
# multivariate diffusion process on probability simplex that converges to Dirichlet distribution with k − 1 independent univariate Jacobi diffusion processes by a classical stick- breaking construction (see Paragraph 3.2 for more details)

# %%
sb = UnitStickBreakingTransform()

# %% [markdown]
# ### Computing Importance Sampling Weights
#
# Importance sampling is often needed to stabilize the training of diffusion model with likelihood weighting, since the scores for the forward diffusion transition density functions are usually large when time is small. Importance sampling is thus used as a variance reduction technique that samples time non-uniformly during training. By sampling time points where the scale of the score is higher more often and down-weight the sample loss accordingly, the variance of the gradient can be reduced. We determine the importance sampling weight based on the scale of the scores at each time point observed empirically.

# %%
n_time_steps = timepoints.shape[0]

time_dependent_cums = torch.zeros(n_time_steps).to(device)
time_dependent_counts = torch.zeros(n_time_steps).to(device)

for i, x in enumerate(weights_est_dl):
    x = binary_to_onehot(x.squeeze())
    random_t = torch.randint(0, n_time_steps, (x.shape[0],))
    order = np.random.permutation(np.arange(C))
    
    # There are two options for using presampled noise: 
    # First one is regular approach and second one is fast sampling (see Appendix A.4 for more info)
    perturbed_x, perturbed_x_grad = diffusion_factory(
        x, random_t, v_one, v_zero, v_one_loggrad, v_zero_loggrad, alpha, beta
    )
    # perturbed_x, perturbed_x_grad = diffusion_fast_flatdirichlet(x, random_t, v_one, v_one_loggrad)
    
    perturbed_x = perturbed_x.to(device)
    perturbed_x_grad = perturbed_x_grad.to(device)
    random_t = random_t.to(device)
    
    # Transform data from x space to v space, where diffusion happens
    order = np.random.permutation(np.arange(C))
    if random_order:
        perturbed_v = sb._inverse(perturbed_x[..., order], prevent_nan=True).detach()
    else:
        perturbed_v = sb._inverse(perturbed_x, prevent_nan=True).detach()

    # Computing score. gx_to_gv transforms gradient in x space to gradient in v space
    if random_order:
        time_dependent_cums[random_t] += (
            (perturbed_v * (1 - perturbed_v)
                * s[(None,) * (x.ndim - 1)]
                * gx_to_gv(perturbed_x_grad[..., order], perturbed_x[..., order],
                           compute_gradlogdet=False)** 2
            ).view(x.shape[0], -1).mean(dim=1).detach()
        )
    else:
        time_dependent_cums[random_t] += (
            (perturbed_v * (1 - perturbed_v)
                * s[(None,) * (x.ndim - 1)]
                * gx_to_gv(perturbed_x_grad, perturbed_x, compute_gradlogdet=False)** 2
            ).view(x.shape[0], -1).mean(dim=1).detach()
        )
        
    time_dependent_counts[random_t] += 1
    
time_dependent_weights = time_dependent_cums / time_dependent_counts
time_dependent_weights = time_dependent_weights / time_dependent_weights.mean()

# %% [markdown]
# The following plot verifies that our importance sampling weights are nice. It should be monotonic decreasing curve.

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
plt.plot(np.arange(1, n_time_steps + 1), time_dependent_weights.cpu())

# %% [markdown]
# ### Training

# %% [markdown]
# The following code trains the model and do validation check every 10 epochs.

# %%
torch.set_default_dtype(torch.float32)

# Defining a model
score_model = ScoreNet(channels=[64, 128, 256, 512], embed_dim=512)
score_model = score_model.to(device)
score_model.train()

# Defining optimizer
lr = 5e-4
optimizer = Adam(score_model.parameters(), lr=lr, weight_decay=1e-10)

timepoints = timepoints.cuda()

tqdm_epoch = tqdm.notebook.trange(num_epochs)
for epoch in tqdm_epoch:
    avg_loss = 0.0
    num_items = 0

    for x in training_dl:
        x = binary_to_onehot(x.squeeze())
        random_t = torch.LongTensor(
            np.random.choice(
                np.arange(n_time_steps),
                size=x.shape[0],
                p=(
                    torch.sqrt(time_dependent_weights)
                    / torch.sqrt(time_dependent_weights).sum()
                )
                .cpu()
                .detach()
                .numpy(),
            )
        ).to(device)
        
        # Similarly to computing importance sampling weights, there are two options 
        perturbed_x, perturbed_x_grad = diffusion_factory(
            x, random_t, v_one, v_zero, v_one_loggrad, v_zero_loggrad, alpha, beta
        )
        # perturbed_x, perturbed_x_grad = diffusion_fast_flatdirichlet(x, random_t, v_one, v_one_loggrad)
        
        perturbed_x = perturbed_x.to(device)
        perturbed_x_grad = perturbed_x_grad.to(device)
        random_t = random_t.to(device)
        random_timepoints = timepoints[random_t]
        
        # Doing score estimation via neural network
        score = score_model(perturbed_x, random_timepoints)
        
        # Computing loss function
        perturbed_v = sb._inverse(perturbed_x, prevent_nan=True).detach()
        loss = torch.mean(
            torch.mean(
                1/ (torch.sqrt(time_dependent_weights))[random_t][
                    (...,) + (None,) * (x.ndim - 1)]
                * s[(None,) * (x.ndim - 1)]
                * perturbed_v * (1 - perturbed_v)
                * (gx_to_gv(
                        score, perturbed_x, create_graph=True, compute_gradlogdet=False
                    ) - gx_to_gv(perturbed_x_grad, perturbed_x, compute_gradlogdet=False)
                  ) ** 2,
                dim=(1))
        )

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        avg_loss += loss.item() * x.shape[0]
        num_items += x.shape[0]

    # Print the averaged training loss so far.
    tqdm_epoch.set_description("Average Loss: {:5f}".format(avg_loss / num_items))

    # Doing validation check every 10 epochs.
    if epoch % 10 == 0:
        valid_avg_loss = 0.0
        valid_num_items = 0
        
        for x in valid_datasets:
            
            x = binary_to_onehot(x.squeeze())
            random_t = torch.LongTensor(
                np.random.choice(
                    np.arange(n_time_steps),
                    size=x.shape[0],
                    p=(
                        torch.sqrt(time_dependent_weights)
                        / torch.sqrt(time_dependent_weights).sum()
                    ).cpu().detach().numpy(),
                )
            ).to(device)
            
            perturbed_x, perturbed_x_grad = diffusion_factory(
                x, random_t, v_one, v_zero, v_one_loggrad, v_zero_loggrad, alpha, beta
            )
            # perturbed_x, perturbed_x_grad = diffusion_fast_flatdirichlet(x, random_t, v_one, v_one_loggrad)
            
            perturbed_x = perturbed_x.to(device)
            perturbed_x_grad = perturbed_x_grad.to(device)
            random_t = random_t.to(device)
            random_timepoints = timepoints[random_t]

            score = score_model(perturbed_x, random_timepoints)
            perturbed_v = sb._inverse(perturbed_x, prevent_nan=True).detach()
            
            loss = torch.mean(
                torch.mean(
                    1 / (torch.sqrt(time_dependent_weights))[random_t][
                        (...,) + (None,) * (x.ndim - 1)]
                    * s[(None,) * (x.ndim - 1)]
                    * perturbed_v * (1 - perturbed_v)
                    * (gx_to_gv(
                            score, perturbed_x,
                            create_graph=True,
                            compute_gradlogdet=False,
                        ) - gx_to_gv(
                            perturbed_x_grad, perturbed_x, compute_gradlogdet=False)
                    )** 2,
                    dim=(1))
            )

            valid_avg_loss += loss.item() * x.shape[0]
            valid_num_items += x.shape[0]

        print("Average Loss: {:5f}".format(valid_avg_loss / valid_num_items))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Average Loss: 0.359942
# Average Loss: 0.130493
# Average Loss: 0.123472
# Average Loss: 0.116315
# Average Loss: 0.117854

# %% [markdown]
# ### Sampling Examples from Dataset.

# %% [markdown]
# Let's sample a few examples from the model by using simple Euler-Maruyama sampler.

# %%
# generate samples from trained model
torch.set_default_dtype(torch.float32)
score_model.eval()

device = 'cuda' 

sample_batch_size = 64 
sampler = Euler_Maruyama_sampler ## Generate samples using the specified sampler.

samples = sampler(score_model, (28, 28, 2),
                        batch_size=sample_batch_size,
                        max_time= 4,
                        min_time=0.01, 
                        num_steps=100, 
                        eps=1e-5,
                        device=device)

samples = samples.clamp(0.0, 1.0)
sample_grid = make_grid(samples[:,None, :,:,0].detach().cpu(), nrow=int(np.sqrt(sample_batch_size)))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# We also propose technique called **time dialation** to improve sample quality (see Appendix A.5 and B.9).
#
# Comparing to unbiasedly sample from the learned model distribution, it is often desirable to sample near the high probability density regions, which often corresponds to higher quality samples in suitable application. Time dilation is applicable to reverse diffusion sampling without modifying the score model, when a flat distribution such as the flat Dirichlet distribution is the stationary distribution. Our sampler implementation support time dilation technique out-of-box.

# %%
#generate samples with time dilation

samples = sampler(score_model,
                        (28,28,2),
                        batch_size=sample_batch_size,
                        max_time= 4,
                        min_time=0.01,
                        num_steps=100,
                        time_dilation=8,
                        time_dilation_start_time=1,
                        eps=1e-5,
                        device=device)

## Sample visualization.
samples = samples.clamp(0.0, 1.0)
sample_grid = make_grid(samples[:,None, :,:,0].detach().cpu(), nrow=int(np.sqrt(sample_batch_size)))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()
# Out:
#   0%|          | 0/275 [00:00<?, ?it/s]

# %% [markdown]
# ### Computing Negative Log Likelihood (ELBO) in Discrete Space
#
# We can estimate likelihood using probability flow ODE. Our formulation allows both computing the likelihood from
# the continuous distribution over the simplex, and computing a variation lower-bound of the likelihood of discrete data. The ELBO formulation is chosen so that the diffusion model training will also minimize the variational gap of this ELBO, which reduces to the KL divergence between the forward diffusion density and the reverse diffusion density up to a constant when minimum time is close to zero. The following code estimates ELBO based on test data.

# %%
# compute NLL (ELBO) in discrete space
score_model.cuda()
score_model.eval()

all_bpds = 0.0
all_items = 0
min_time = timepoints[0].item()
max_time = timepoints[-1].item()

logliks = []
loglikxs = []
qlogs = []

# note that as the NLL estimate used the stochastic Huchinson's trace estimator
# it generally requires multiple passes to obtain a stable estimate
for x in test_dl:
    x = binary_to_onehot(x).squeeze()
    
    perturbed_x, _ = diffusion_factory(x.cpu(), torch.zeros(x.shape[0]).long(), v_one, v_zero,
                                        v_one_loggrad, v_zero_loggrad, alpha, beta)
    
    perturbed_x = perturbed_x.to(device)
    x = x.to(device)
    v = sb._inverse(x, prevent_nan=False)
    perturbed_v = sb._inverse(perturbed_x, prevent_nan=False)

    z, loglik = ode_likelihood(
        perturbed_v, score_model,
        eps=1e-5, min_time=min_time, max_time=max_time, device=device,
        alpha=None, beta=None, speed_balanced=speed_balanced)
    N = np.prod(x.shape[1:-1])
    loglik = loglik / N

    loglikx = (torch.log(perturbed_x) * (x == 1)).sum(-1).mean()

    torch.set_default_dtype(torch.float64)

    qlog = jacobi_diffusion_density(
        v.double(), perturbed_v.double(), min_time,
        alpha.to(device), beta.to(device),
        order=1000,
        speed_balanced=speed_balanced,
    ).log()
    
    for i, (a, b) in enumerate(zip(alpha.to(device), beta.to(device))):
        B = Beta(a, b)
        nanmask = torch.isnan(qlog[..., i])
        qlog[..., i][nanmask] = B.log_prob(perturbed_v[..., i][nanmask].double())
        
    qlog = (qlog.sum(-1) + sb.log_abs_det_jacobian(perturbed_v)).mean().float()
    torch.set_default_dtype(torch.float32)

    elbo = loglik + loglikx - qlog

    logliks.append(loglik.cpu().detach().numpy())
    loglikxs.append(loglikx.cpu().detach().numpy())
    qlogs.append(qlog.cpu().detach().numpy())

    bpd = -(elbo.cpu().detach().numpy()) / np.log(2)
    all_bpds += bpd.sum()
    all_items += bpd.shape[0]
    print("Average bits: {:5f}".format(all_bpds / all_items))
    print("Average nats: {:5f}".format(all_bpds / all_items * np.log(2)))
# Out:
# Number of function evaluations: 281
# Average bits: 0.128066
# Average nats: 0.088769
# Number of function evaluations: 260
# Average bits: 0.143960
# Average nats: 0.099786
# Number of function evaluations: 263
# Average bits: 0.116049
# Average nats: 0.080439
# Number of function evaluations: 260
# Average bits: 0.108033
# Average nats: 0.074883
# Number of function evaluations: 287
# Average bits: 0.120435
# Average nats: 0.083479
# Number of function evaluations: 263
# Average bits: 0.131108
# Average nats: 0.090877
# Number of function evaluations: 278
# Average bits: 0.136297
# Average nats: 0.094474
# Number of function evaluations: 281
# Average bits: 0.136599
# Average nats: 0.094683
# Number of function evaluations: 281
# Average bits: 0.149065
# Average nats: 0.103324
# Number of function evaluations: 287
# Average bits: 0.154219
# Average nats: 0.106896
# Number of function evaluations: 269
# Average bits: 0.155191
# Average nats: 0.107570
# Number of function evaluations: 293
# Average bits: 0.156425
# Average nats: 0.108426
# Number of function evaluations: 263
# Average bits: 0.156674
# Average nats: 0.108598
# Number of function evaluations: 269
# Average bits: 0.160278
# Average nats: 0.111096
# Number of function evaluations: 287
# Average bits: 0.155640
# Average nats: 0.107881
# Number of function evaluations: 269
# Average bits: 0.154720
# Average nats: 0.107243
# Number of function evaluations: 281
# Average bits: 0.157065
# Average nats: 0.108869
# Number of function evaluations: 275
# Average bits: 0.162766
# Average nats: 0.112821
# Number of function evaluations: 269
# Average bits: 0.161985
# Average nats: 0.112280
# Number of function evaluations: 278
# Average bits: 0.162180
# Average nats: 0.112415
# Number of function evaluations: 272
# Average bits: 0.162339
# Average nats: 0.112525
# Number of function evaluations: 263
# Average bits: 0.162086
# Average nats: 0.112350
# Number of function evaluations: 272
# Average bits: 0.163588
# Average nats: 0.113391
# Number of function evaluations: 281
# Average bits: 0.163504
# Average nats: 0.113332
# Number of function evaluations: 281
# Average bits: 0.164557
# Average nats: 0.114062
# Number of function evaluations: 272
# Average bits: 0.163944
# Average nats: 0.113638
# Number of function evaluations: 290
# Average bits: 0.161622
# Average nats: 0.112028
# Number of function evaluations: 257
# Average bits: 0.161442
# Average nats: 0.111903
# Number of function evaluations: 296
# Average bits: 0.162767
# Average nats: 0.112822
# Number of function evaluations: 281
# Average bits: 0.161575
# Average nats: 0.111995
# Number of function evaluations: 275
# Average bits: 0.159844
# Average nats: 0.110795
# Number of function evaluations: 284
# Average bits: 0.162643
# Average nats: 0.112735
# Number of function evaluations: 278
# Average bits: 0.165399
# Average nats: 0.114646
# Number of function evaluations: 272
# Average bits: 0.166346
# Average nats: 0.115302
# Number of function evaluations: 281
# Average bits: 0.166164
# Average nats: 0.115176
# Number of function evaluations: 290
# Average bits: 0.167347
# Average nats: 0.115996
# Number of function evaluations: 278
# Average bits: 0.166717
# Average nats: 0.115559
# Number of function evaluations: 263
# Average bits: 0.168342
# Average nats: 0.116686
# Number of function evaluations: 281
# Average bits: 0.169344
# Average nats: 0.117380
# Number of function evaluations: 272
# Average bits: 0.168385
# Average nats: 0.116716
# Number of function evaluations: 284
# Average bits: 0.167994
# Average nats: 0.116445
# Number of function evaluations: 275
# Average bits: 0.168981
# Average nats: 0.117128
# Number of function evaluations: 281
# Average bits: 0.172003
# Average nats: 0.119223
# Number of function evaluations: 281
# Average bits: 0.169516
# Average nats: 0.117500
# Number of function evaluations: 269
# Average bits: 0.169064
# Average nats: 0.117186
# Number of function evaluations: 269
# Average bits: 0.168164
# Average nats: 0.116562
# Number of function evaluations: 287
# Average bits: 0.168928
# Average nats: 0.117092
# Number of function evaluations: 275
# Average bits: 0.169487
# Average nats: 0.117480
# Number of function evaluations: 284
# Average bits: 0.168170
# Average nats: 0.116567
# Number of function evaluations: 278
# Average bits: 0.166836
# Average nats: 0.115642
# Number of function evaluations: 293
# Average bits: 0.166366
# Average nats: 0.115316
# Number of function evaluations: 278
# Average bits: 0.167942
# Average nats: 0.116408
# Number of function evaluations: 287
# Average bits: 0.168266
# Average nats: 0.116633
# Number of function evaluations: 275
# Average bits: 0.169799
# Average nats: 0.117695
# Number of function evaluations: 281
# Average bits: 0.170864
# Average nats: 0.118434
# Number of function evaluations: 278
# Average bits: 0.171602
# Average nats: 0.118946
# Number of function evaluations: 290
# Average bits: 0.170411
# Average nats: 0.118120
# Number of function evaluations: 278
# Average bits: 0.168205
# Average nats: 0.116591
# Number of function evaluations: 287
# Average bits: 0.168462
# Average nats: 0.116769
# Number of function evaluations: 269
# Average bits: 0.168586
# Average nats: 0.116855
# Number of function evaluations: 293
# Average bits: 0.169574
# Average nats: 0.117540
# Number of function evaluations: 278
# Average bits: 0.171305
# Average nats: 0.118740
# Number of function evaluations: 284
# Average bits: 0.171183
# Average nats: 0.118655
# Number of function evaluations: 272
# Average bits: 0.169252
# Average nats: 0.117317
# Number of function evaluations: 260
# Average bits: 0.169471
# Average nats: 0.117468
# Number of function evaluations: 281
# Average bits: 0.168834
# Average nats: 0.117027
# Number of function evaluations: 278
# Average bits: 0.170354
# Average nats: 0.118080
# Number of function evaluations: 260
# Average bits: 0.170714
# Average nats: 0.118330
# Number of function evaluations: 284
# Average bits: 0.170861
# Average nats: 0.118432
# Number of function evaluations: 293
# Average bits: 0.170778
# Average nats: 0.118374
# Number of function evaluations: 278
# Average bits: 0.170787
# Average nats: 0.118380
# Number of function evaluations: 260
# Average bits: 0.171824
# Average nats: 0.119099
# Number of function evaluations: 278
# Average bits: 0.171646
# Average nats: 0.118976
# Number of function evaluations: 287
# Average bits: 0.171809
# Average nats: 0.119089
# Number of function evaluations: 266
# Average bits: 0.171519
# Average nats: 0.118888
# Number of function evaluations: 284
# Average bits: 0.170925
# Average nats: 0.118476
# Number of function evaluations: 278
# Average bits: 0.171707
# Average nats: 0.119018
# Number of function evaluations: 269
# Average bits: 0.172799
# Average nats: 0.119775
# Number of function evaluations: 284
# Average bits: 0.173875
# Average nats: 0.120521
# Number of function evaluations: 284
# Average bits: 0.173673
# Average nats: 0.120381
# Number of function evaluations: 275
# Average bits: 0.173227
# Average nats: 0.120072
# Number of function evaluations: 278
# Average bits: 0.174184
# Average nats: 0.120735
# Number of function evaluations: 275
# Average bits: 0.174367
# Average nats: 0.120862
# Number of function evaluations: 272
# Average bits: 0.174129
# Average nats: 0.120697
# Number of function evaluations: 281
# Average bits: 0.174738
# Average nats: 0.121119
# Number of function evaluations: 287
# Average bits: 0.174834
# Average nats: 0.121185
# Number of function evaluations: 275
# Average bits: 0.175367
# Average nats: 0.121555
# Number of function evaluations: 266
# Average bits: 0.173986
# Average nats: 0.120598
# Number of function evaluations: 290
# Average bits: 0.174420
# Average nats: 0.120899
# Number of function evaluations: 260
# Average bits: 0.174637
# Average nats: 0.121049
# Number of function evaluations: 272
# Average bits: 0.174773
# Average nats: 0.121144
# Number of function evaluations: 266
# Average bits: 0.174194
# Average nats: 0.120742
# Number of function evaluations: 281
# Average bits: 0.174312
# Average nats: 0.120824
# Number of function evaluations: 272
# Average bits: 0.174259
# Average nats: 0.120787
# Number of function evaluations: 293
# Average bits: 0.174018
# Average nats: 0.120620
# Number of function evaluations: 293
# Average bits: 0.173957
# Average nats: 0.120578
# Number of function evaluations: 275
# Average bits: 0.173710
# Average nats: 0.120406
# Number of function evaluations: 278
# Average bits: 0.174353
# Average nats: 0.120853
# Number of function evaluations: 287
# Average bits: 0.174556
# Average nats: 0.120993
# Number of function evaluations: 281
# Average bits: 0.174128
# Average nats: 0.120697
# Number of function evaluations: 287
# Average bits: 0.174361
# Average nats: 0.120858
# Number of function evaluations: 260
# Average bits: 0.174179
# Average nats: 0.120732
# Number of function evaluations: 272
# Average bits: 0.174890
# Average nats: 0.121224
# Number of function evaluations: 278
# Average bits: 0.173496
# Average nats: 0.120258
# Number of function evaluations: 269
# Average bits: 0.174008
# Average nats: 0.120613
# Number of function evaluations: 272
# Average bits: 0.173016
# Average nats: 0.119926
# Number of function evaluations: 269
# Average bits: 0.172309
# Average nats: 0.119436
# Number of function evaluations: 290
# Average bits: 0.172299
# Average nats: 0.119428
# Number of function evaluations: 269
# Average bits: 0.171948
# Average nats: 0.119185
# Number of function evaluations: 275
# Average bits: 0.171735
# Average nats: 0.119038
# Number of function evaluations: 284
# Average bits: 0.171529
# Average nats: 0.118895
# Number of function evaluations: 281
# Average bits: 0.171739
# Average nats: 0.119040
# Number of function evaluations: 266
# Average bits: 0.171634
# Average nats: 0.118968
# Number of function evaluations: 284
# Average bits: 0.171405
# Average nats: 0.118809
# Number of function evaluations: 290
# Average bits: 0.171566
# Average nats: 0.118920
# Number of function evaluations: 278
# Average bits: 0.172242
# Average nats: 0.119389
# Number of function evaluations: 278
# Average bits: 0.172816
# Average nats: 0.119787
# Number of function evaluations: 287
# Average bits: 0.172645
# Average nats: 0.119668
# Number of function evaluations: 269
# Average bits: 0.173009
# Average nats: 0.119921
# Number of function evaluations: 272
# Average bits: 0.172647
# Average nats: 0.119670
# Number of function evaluations: 281
# Average bits: 0.173338
# Average nats: 0.120149
# Number of function evaluations: 254
# Average bits: 0.173046
# Average nats: 0.119947
# Number of function evaluations: 275
# Average bits: 0.172640
# Average nats: 0.119665
# Number of function evaluations: 287
# Average bits: 0.172157
# Average nats: 0.119330
# Number of function evaluations: 278
# Average bits: 0.172278
# Average nats: 0.119414
# Number of function evaluations: 287
# Average bits: 0.172912
# Average nats: 0.119853
# Number of function evaluations: 272
# Average bits: 0.173523
# Average nats: 0.120277
# Number of function evaluations: 263
# Average bits: 0.173241
# Average nats: 0.120081
# Number of function evaluations: 272
# Average bits: 0.174101
# Average nats: 0.120678
# Number of function evaluations: 278
# Average bits: 0.174653
# Average nats: 0.121060
# Number of function evaluations: 284
# Average bits: 0.175165
# Average nats: 0.121415
# Number of function evaluations: 275
# Average bits: 0.175815
# Average nats: 0.121866
# Number of function evaluations: 284
# Average bits: 0.175618
# Average nats: 0.121729
# Number of function evaluations: 254
# Average bits: 0.175882
# Average nats: 0.121912
# Number of function evaluations: 272
# Average bits: 0.176131
# Average nats: 0.122085
# Number of function evaluations: 287
# Average bits: 0.176084
# Average nats: 0.122052
# Number of function evaluations: 275
# Average bits: 0.175772
# Average nats: 0.121836
# Number of function evaluations: 278
# Average bits: 0.176573
# Average nats: 0.122391
# Number of function evaluations: 278
# Average bits: 0.176460
# Average nats: 0.122313
# Number of function evaluations: 278
# Average bits: 0.176182
# Average nats: 0.122120
# Number of function evaluations: 281
# Average bits: 0.175991
# Average nats: 0.121987
# Number of function evaluations: 287
# Average bits: 0.176503
# Average nats: 0.122342
# Number of function evaluations: 272
# Average bits: 0.176471
# Average nats: 0.122320
# Number of function evaluations: 284
# Average bits: 0.176400
# Average nats: 0.122271
# Number of function evaluations: 287
# Average bits: 0.176265
# Average nats: 0.122177
# Number of function evaluations: 287
# Average bits: 0.175684
# Average nats: 0.121775
# Number of function evaluations: 272
# Average bits: 0.175388
# Average nats: 0.121570
# Number of function evaluations: 281
# Average bits: 0.175154
# Average nats: 0.121407
# Number of function evaluations: 257
# Average bits: 0.175302
# Average nats: 0.121510
# Number of function evaluations: 269
# Average bits: 0.175599
# Average nats: 0.121716
# Number of function evaluations: 287
# Average bits: 0.176190
# Average nats: 0.122126
# Number of function evaluations: 287
# Average bits: 0.176720
# Average nats: 0.122493
# Number of function evaluations: 278
# Average bits: 0.176438
# Average nats: 0.122297
# Number of function evaluations: 278
# Average bits: 0.176450
# Average nats: 0.122306
# Number of function evaluations: 275
# Average bits: 0.176752
# Average nats: 0.122515
# Number of function evaluations: 266
# Average bits: 0.176949
# Average nats: 0.122652
# Number of function evaluations: 281
# Average bits: 0.177042
# Average nats: 0.122716
# Number of function evaluations: 275
# Average bits: 0.177635
# Average nats: 0.123127
# Number of function evaluations: 269
# Average bits: 0.177062
# Average nats: 0.122730
# Number of function evaluations: 272
# Average bits: 0.177921
# Average nats: 0.123325
# Number of function evaluations: 287
# Average bits: 0.177712
# Average nats: 0.123181
# Number of function evaluations: 275
# Average bits: 0.177800
# Average nats: 0.123242
# Number of function evaluations: 284
# Average bits: 0.178146
# Average nats: 0.123481
# Number of function evaluations: 272
# Average bits: 0.178147
# Average nats: 0.123482
# Number of function evaluations: 251
# Average bits: 0.177937
# Average nats: 0.123337
# Number of function evaluations: 281
# Average bits: 0.177477
# Average nats: 0.123018
# Number of function evaluations: 278
# Average bits: 0.177699
# Average nats: 0.123171
# Number of function evaluations: 287
# Average bits: 0.177980
# Average nats: 0.123367
# Number of function evaluations: 278
# Average bits: 0.178141
# Average nats: 0.123478
# Number of function evaluations: 290
# Average bits: 0.178342
# Average nats: 0.123617
# Number of function evaluations: 272
# Average bits: 0.178679
# Average nats: 0.123851
# Number of function evaluations: 272
# Average bits: 0.178910
# Average nats: 0.124011
# Number of function evaluations: 281
# Average bits: 0.178716
# Average nats: 0.123877
# Number of function evaluations: 272
# Average bits: 0.178965
# Average nats: 0.124049
# Number of function evaluations: 290
# Average bits: 0.179112
# Average nats: 0.124151
# Number of function evaluations: 263
# Average bits: 0.179215
# Average nats: 0.124222
# Number of function evaluations: 281
# Average bits: 0.179073
# Average nats: 0.124124
# Number of function evaluations: 269
# Average bits: 0.179228
# Average nats: 0.124231
# Number of function evaluations: 275
# Average bits: 0.179136
# Average nats: 0.124167
# Number of function evaluations: 281
# Average bits: 0.179149
# Average nats: 0.124177
# Number of function evaluations: 275
# Average bits: 0.179449
# Average nats: 0.124385
# Number of function evaluations: 287
# Average bits: 0.179629
# Average nats: 0.124509
# Number of function evaluations: 290
# Average bits: 0.179905
# Average nats: 0.124700
# Number of function evaluations: 278
# Average bits: 0.179691
# Average nats: 0.124552
# Number of function evaluations: 284
# Average bits: 0.179116
# Average nats: 0.124154
# Number of function evaluations: 278
# Average bits: 0.178933
# Average nats: 0.124027
# Number of function evaluations: 290
# Average bits: 0.179375
# Average nats: 0.124333
# Number of function evaluations: 272
# Average bits: 0.179876
# Average nats: 0.124680
# Number of function evaluations: 278
# Average bits: 0.180104
# Average nats: 0.124839
# Number of function evaluations: 281
# Average bits: 0.180456
# Average nats: 0.125083
# Number of function evaluations: 272
# Average bits: 0.180174
# Average nats: 0.124887
# Number of function evaluations: 272
# Average bits: 0.180512
# Average nats: 0.125122
# Number of function evaluations: 281
# Average bits: 0.180552
# Average nats: 0.125149
# Number of function evaluations: 260
# Average bits: 0.180592
# Average nats: 0.125177
# Number of function evaluations: 281
# Average bits: 0.180262
# Average nats: 0.124948
# Number of function evaluations: 278
# Average bits: 0.180680
# Average nats: 0.125238
# Number of function evaluations: 257
# Average bits: 0.180630
# Average nats: 0.125203
# Number of function evaluations: 272
# Average bits: 0.181142
# Average nats: 0.125558
# Number of function evaluations: 272
# Average bits: 0.180978
# Average nats: 0.125444
# Number of function evaluations: 269
# Average bits: 0.180568
# Average nats: 0.125160
# Number of function evaluations: 281
# Average bits: 0.181080
# Average nats: 0.125515
# Number of function evaluations: 281
# Average bits: 0.180762
# Average nats: 0.125294
# Number of function evaluations: 287
# Average bits: 0.180459
# Average nats: 0.125085
# Number of function evaluations: 263
# Average bits: 0.180736
# Average nats: 0.125276
# Number of function evaluations: 281
# Average bits: 0.181170
# Average nats: 0.125577
# Number of function evaluations: 284
# Average bits: 0.181320
# Average nats: 0.125681
# Number of function evaluations: 263
# Average bits: 0.181809
# Average nats: 0.126020
# Number of function evaluations: 290
# Average bits: 0.182020
# Average nats: 0.126167
# Number of function evaluations: 272
# Average bits: 0.182056
# Average nats: 0.126192
# Number of function evaluations: 269
# Average bits: 0.181834
# Average nats: 0.126038
# Number of function evaluations: 275
# Average bits: 0.182297
# Average nats: 0.126358
# Number of function evaluations: 290
# Average bits: 0.182619
# Average nats: 0.126582
# Number of function evaluations: 257
# Average bits: 0.182937
# Average nats: 0.126802
# Number of function evaluations: 278
# Average bits: 0.183489
# Average nats: 0.127185
# Number of function evaluations: 278
# Average bits: 0.183837
# Average nats: 0.127426
# Number of function evaluations: 278
# Average bits: 0.183652
# Average nats: 0.127298
# Number of function evaluations: 272
# Average bits: 0.183535
# Average nats: 0.127217
# Number of function evaluations: 278
# Average bits: 0.183511
# Average nats: 0.127200
# Number of function evaluations: 272
# Average bits: 0.183030
# Average nats: 0.126867
# Number of function evaluations: 263
# Average bits: 0.182704
# Average nats: 0.126641
# Number of function evaluations: 269
# Average bits: 0.183095
# Average nats: 0.126912
# Number of function evaluations: 284
# Average bits: 0.182351
# Average nats: 0.126396
# Number of function evaluations: 281
# Average bits: 0.182333
# Average nats: 0.126384
# Number of function evaluations: 272
# Average bits: 0.182037
# Average nats: 0.126179
# Number of function evaluations: 275
# Average bits: 0.182312
# Average nats: 0.126369
# Number of function evaluations: 278
# Average bits: 0.181997
# Average nats: 0.126151
# Number of function evaluations: 278
# Average bits: 0.182191
# Average nats: 0.126285
# Number of function evaluations: 272
# Average bits: 0.182298
# Average nats: 0.126359
# Number of function evaluations: 284
# Average bits: 0.182074
# Average nats: 0.126204
# Number of function evaluations: 278
# Average bits: 0.181998
# Average nats: 0.126151
# Number of function evaluations: 275
# Average bits: 0.181933
# Average nats: 0.126107
# Number of function evaluations: 269
# Average bits: 0.182138
# Average nats: 0.126249
# Number of function evaluations: 269
# Average bits: 0.182027
# Average nats: 0.126172
# Number of function evaluations: 260
# Average bits: 0.182234
# Average nats: 0.126315
# Number of function evaluations: 278
# Average bits: 0.181775
# Average nats: 0.125997
# Number of function evaluations: 269
# Average bits: 0.181937
# Average nats: 0.126109
# Number of function evaluations: 269
# Average bits: 0.181979
# Average nats: 0.126138
# Number of function evaluations: 263
# Average bits: 0.181813
# Average nats: 0.126023
# Number of function evaluations: 287
# Average bits: 0.181597
# Average nats: 0.125873
# Number of function evaluations: 278
# Average bits: 0.181657
# Average nats: 0.125915
# Number of function evaluations: 272
# Average bits: 0.181339
# Average nats: 0.125694
# Number of function evaluations: 269
# Average bits: 0.181788
# Average nats: 0.126006
# Number of function evaluations: 293
# Average bits: 0.181919
# Average nats: 0.126097
# Number of function evaluations: 266
# Average bits: 0.181806
# Average nats: 0.126018
# Number of function evaluations: 281
# Average bits: 0.181751
# Average nats: 0.125980
# Number of function evaluations: 269
# Average bits: 0.181681
# Average nats: 0.125932
# Number of function evaluations: 269
# Average bits: 0.181685
# Average nats: 0.125934
# Number of function evaluations: 278
# Average bits: 0.181855
# Average nats: 0.126052
# Number of function evaluations: 281
# Average bits: 0.181968
# Average nats: 0.126130
# Number of function evaluations: 287
# Average bits: 0.182031
# Average nats: 0.126174
# Number of function evaluations: 272
# Average bits: 0.182301
# Average nats: 0.126361
# Number of function evaluations: 272
# Average bits: 0.182305
# Average nats: 0.126364
# Number of function evaluations: 272
# Average bits: 0.182171
# Average nats: 0.126271
# Number of function evaluations: 284
# Average bits: 0.182358
# Average nats: 0.126401
# Number of function evaluations: 281
# Average bits: 0.182180
# Average nats: 0.126278
# Number of function evaluations: 281
# Average bits: 0.182580
# Average nats: 0.126555
# Number of function evaluations: 293
# Average bits: 0.182488
# Average nats: 0.126491
# Number of function evaluations: 281
# Average bits: 0.182671
# Average nats: 0.126618
# Number of function evaluations: 266
# Average bits: 0.182709
# Average nats: 0.126644
# Number of function evaluations: 284
# Average bits: 0.182709
# Average nats: 0.126645
# Number of function evaluations: 287
# Average bits: 0.182605
# Average nats: 0.126572
# Number of function evaluations: 263
# Average bits: 0.182777
# Average nats: 0.126692
# Number of function evaluations: 269
# Average bits: 0.182561
# Average nats: 0.126542
# Number of function evaluations: 284
# Average bits: 0.182577
# Average nats: 0.126552
# Number of function evaluations: 281
# Average bits: 0.182456
# Average nats: 0.126469
# Number of function evaluations: 278
# Average bits: 0.182242
# Average nats: 0.126321
# Number of function evaluations: 281
# Average bits: 0.182272
# Average nats: 0.126341
# Number of function evaluations: 287
# Average bits: 0.182288
# Average nats: 0.126352
# Number of function evaluations: 281
# Average bits: 0.182445
# Average nats: 0.126461
# Number of function evaluations: 284
# Average bits: 0.182709
# Average nats: 0.126644
# Number of function evaluations: 287
# Average bits: 0.182919
# Average nats: 0.126790
# Number of function evaluations: 281
# Average bits: 0.182903
# Average nats: 0.126779
# Number of function evaluations: 278
# Average bits: 0.183096
# Average nats: 0.126913
# Number of function evaluations: 278
# Average bits: 0.183352
# Average nats: 0.127090
# Number of function evaluations: 278
# Average bits: 0.183534
# Average nats: 0.127216
# Number of function evaluations: 263
# Average bits: 0.183872
# Average nats: 0.127451
# Number of function evaluations: 272
# Average bits: 0.183863
# Average nats: 0.127444
# Number of function evaluations: 284
# Average bits: 0.183920
# Average nats: 0.127484
# Number of function evaluations: 278
# Average bits: 0.184015
# Average nats: 0.127549
# Number of function evaluations: 275
# Average bits: 0.183942
# Average nats: 0.127499
# Number of function evaluations: 278
# Average bits: 0.183823
# Average nats: 0.127416
# Number of function evaluations: 278
# Average bits: 0.183894
# Average nats: 0.127466
# Number of function evaluations: 269
# Average bits: 0.184069
# Average nats: 0.127587
# Number of function evaluations: 260
# Average bits: 0.183792
# Average nats: 0.127395
# Number of function evaluations: 278
# Average bits: 0.183937
# Average nats: 0.127496
# Number of function evaluations: 260
# Average bits: 0.183986
# Average nats: 0.127530
# Number of function evaluations: 275
# Average bits: 0.183901
# Average nats: 0.127471
# Number of function evaluations: 284
# Average bits: 0.183837
# Average nats: 0.127426
# Number of function evaluations: 287
# Average bits: 0.183967
# Average nats: 0.127517
# Number of function evaluations: 284
# Average bits: 0.184103
# Average nats: 0.127610
# Number of function evaluations: 278
# Average bits: 0.183978
# Average nats: 0.127524
# Number of function evaluations: 284
# Average bits: 0.183746
# Average nats: 0.127363
# Number of function evaluations: 278
# Average bits: 0.183871
# Average nats: 0.127450
# Number of function evaluations: 284
# Average bits: 0.184026
# Average nats: 0.127557
# Number of function evaluations: 263
# Average bits: 0.184360
# Average nats: 0.127789
# Number of function evaluations: 278
# Average bits: 0.184199
# Average nats: 0.127677
# Number of function evaluations: 263
# Average bits: 0.183905
# Average nats: 0.127473
# Number of function evaluations: 260
# Average bits: 0.183606
# Average nats: 0.127266
# Number of function evaluations: 281
# Average bits: 0.183626
# Average nats: 0.127280
# Number of function evaluations: 287
# Average bits: 0.183680
# Average nats: 0.127317
# Number of function evaluations: 263
# Average bits: 0.183731
# Average nats: 0.127353
# Number of function evaluations: 284
# Average bits: 0.183930
# Average nats: 0.127490
# Number of function evaluations: 272
# Average bits: 0.183745
# Average nats: 0.127362
# Number of function evaluations: 278
# Average bits: 0.183761
# Average nats: 0.127374
# Number of function evaluations: 290
# Average bits: 0.183660
# Average nats: 0.127304
# Number of function evaluations: 281
# Average bits: 0.183283
# Average nats: 0.127042
# Number of function evaluations: 281
# Average bits: 0.183485
# Average nats: 0.127182
# Number of function evaluations: 272
# Average bits: 0.183660
# Average nats: 0.127303
# Number of function evaluations: 272
# Average bits: 0.183855
# Average nats: 0.127438
# Number of function evaluations: 257
# Average bits: 0.183793
# Average nats: 0.127396
# Number of function evaluations: 275
# Average bits: 0.184014
# Average nats: 0.127548
# Number of function evaluations: 278
# Average bits: 0.183909
# Average nats: 0.127476
# Number of function evaluations: 284
# Average bits: 0.183870
# Average nats: 0.127449
